# %% [markdown]
# # Code Section Analysis

# %%
import os

from sqlalchemy import create_engine
import pandas as pd

# %%
USER = 'jupyter'
PASSWORD = os.environ['POSTGRES_PASS']
HOST = 'localhost'
PORT = '5432'
DB = 'expunge'

DATABASE_URI = f"postgresql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB}"
engine = create_engine(DATABASE_URI)

# %%
# %load_ext sql
# %sql {DATABASE_URI}

# %% [markdown]
# Create a table containing all code sections that account for at least 1% of records

# %%
# %%sql
# CREATE TEMPORARY TABLE temp_top_codes AS
# WITH code_distribution AS (
#     SELECT
#         "CodeSection",
#         COUNT(*),
#         ROUND(
#             COUNT(*) * 100.0 / SUM(COUNT(*)) OVER(),
#         2) AS percent
#     FROM expunge_clean
#     GROUP BY "CodeSection"
#     ORDER BY percent DESC
# )
# SELECT
#     *,
#     SUM(percent) OVER(
#         ORDER BY percent DESC
#         ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW
#     ) AS cumulative_percent
# FROM code_distribution
# WHERE percent > 1.0;
# Out:
#  * postgresql://jupyter:***@localhost:5432/expunge
# 22 rows affected.
# []

# %% [markdown]
# These top 22 code sections account for ~62% of the records

# %%
# %%sql
# SELECT *
# FROM temp_top_codes
# Out:
#  * postgresql://jupyter:***@localhost:5432/expunge
# 22 rows affected.
# [('A.46.2-862', 820869, Decimal('9.07'), Decimal('9.07')),
#  ('B.46.2-301', 808278, Decimal('8.93'), Decimal('18.00')),
#  ('46.2-300', 557710, Decimal('6.16'), Decimal('24.16')),
#  ('C.46.2-862', 360087, Decimal('3.98'), Decimal('28.14')),
#  ('18.2-250.1', 319184, Decimal('3.53'), Decimal('31.67')),
#  ('A.18.2-266', 268080, Decimal('2.96'), Decimal('34.63')),
#  ('18.2-95', 232460, Decimal('2.57'), Decimal('37.20')),
#  ('18.2-250', 214542, Decimal('2.37'), Decimal('39.57')),
#  ('A.46.2-852', 207907, Decimal('2.30'), Decimal('41.87')),
#  ('18.2-57', 206629, Decimal('2.28'), Decimal('44.15')),
#  ('18.2-388', 197852, Decimal('2.19'), Decimal('46.34')),
#  ('18.2-248', 177358, Decimal('1.96'), Decimal('48.30')),
#  ('18.2-96', 166912, Decimal('1.84'), Decimal('50.14')),
#  ('18.2-172', 163582, Decimal('1.81'), Decimal('51.95')),
#  ('19.2-306', 130872, Decimal('1.45'), Decimal('53.40')),
#  ('19.2-128', 123867, Decimal('1.37'), Decimal('54.77')),
#  ('A.46.2-707', 112208, Decimal('1.24'), Decimal('56.01')),
#  ('A.46.2-853', 111288, Decimal('1.23'), Decimal('57.24')),
#  ('18.2-119', 108024, Decimal('1.19'), Decimal('58.43')),
#  ('18.2-103', 107282, Decimal('1.18'), Decimal('59.61')),
#  ('18.2-137', 93799, Decimal('1.04'), Decimal('60.65')),
#  ('18.2-178', 91991, Decimal('1.02'), Decimal('61.67'))]

# %% [markdown]
# ## Code Sections by Race

# %% [markdown]
# Overall distribution of race in `expunge`

# %%
# %%sql
# SELECT
#     "Race",
#     COUNT(*),
#     ROUND(
#         COUNT(*) * 100.0 / SUM(COUNT(*)) OVER(),
#     2) AS percent
# FROM expunge_clean
# GROUP BY "Race"
# ORDER BY COUNT(*) DESC
# Out:
#  * postgresql://jupyter:***@localhost:5432/expunge
# 6 rows affected.
# [('White', 4899463, Decimal('54.11')),
#  ('Black', 3579193, Decimal('39.53')),
#  ('Hispanic', 291017, Decimal('3.21')),
#  ('Unknown', 186198, Decimal('2.06')),
#  ('Asian or Pacific Islander', 89262, Decimal('0.99')),
#  ('American Indian or Alaskan Native', 9133, Decimal('0.10'))]

# %% [markdown]
# Below is the racial breakdowns for the top 22 code sections (as found above), with both counts and percents.

# %%
# %%sql
# SELECT
#     c."CodeSection",
#     e."Race",
#     COUNT(*),
#     ROUND(
#         COUNT(*) * 100.0 / SUM(COUNT(*)) OVER(PARTITION BY c."CodeSection"),
#     2) AS percent
# FROM temp_top_codes c
# JOIN expunge_clean e
#     ON c."CodeSection" = e."CodeSection"
# GROUP BY c."CodeSection", e."Race"
# ORDER BY c."CodeSection", COUNT(*) DESC
# Out:
#  * postgresql://jupyter:***@localhost:5432/expunge
# 132 rows affected.
# [('18.2-103', 'White', 67089, Decimal('62.54')),
#  ('18.2-103', 'Black', 37831, Decimal('35.26')),
#  ('18.2-103', 'Hispanic', 971, Decimal('0.91')),
#  ('18.2-103', 'Asian or Pacific Islander', 701, Decimal('0.65')),
#  ('18.2-103', 'Unknown', 633, Decimal('0.59')),
#  ('18.2-103', 'American Indian or Alaskan Native', 57, Decimal('0.05')),
#  ('18.2-119', 'Black', 58075, Decimal('53.76')),
#  ('18.2-119', 'White', 47865, Decimal('44.31')),
#  ('18.2-119', 'Hispanic', 732, Decimal('0.68')),
#  ('18.2-119', 'Unknown', 669, Decimal('0.62')),
#  ('18.2-119', 'Asian or Pacific Islander', 626, Decimal('0.58')),
#  ('18.2-119', 'American Indian or Alaskan Native', 57, Decimal('0.05')),
#  ('18.2-137', 'White', 56259, Decimal('59.98')),
#  ('18.2-137', 'Black', 35784, Decimal('38.15')),
#  ('18.2-137', 'Unknown', 706, Decimal('0.75')),
#  ('18.2-137', 'Hispanic', 500, Decimal('0.53')),
#  ('18.2-137', 'Asian or Pacific Islander', 500, Decimal('0.53')),
#  ('18.2-137', 'American Indian or Alaskan Native', 50, Decimal('0.05')),
#  ('18.2-172', 'White', 111782, Decimal('68.33')),
#  ('18.2-172', 'Black', 49886, Decimal('30.50')),
#  ('18.2-172', 'Unknown', 781, Decimal('0.48')),
#  ('18.2-172', 'Asian or Pacific Islander', 565, Decimal('0.35')),
#  ('18.2-172', 'Hispanic', 489, Decimal('0.30')),
#  ('18.2-172', 'American Indian or Alaskan Native', 79, Decimal('0.05')),
#  ('18.2-178', 'White', 57390, Decimal('62.39')),
#  ('18.2-178', 'Black', 32968, Decimal('35.84')),
#  ('18.2-178', 'Unknown', 704, Decimal('0.77')),
#  ('18.2-178', 'Asian or Pacific Islander', 678, Decimal('0.74')),
#  ('18.2-178', 'Hispanic', 224, Decimal('0.24')),
#  ('18.2-178', 'American Indian or Alaskan Native', 27, Decimal('0.03')),
#  ('18.2-248', 'Black', 94070, Decimal('53.04')),
#  ('18.2-248', 'White', 79410, Decimal('44.77')),
#  ('18.2-248', 'Hispanic', 1810, Decimal('1.02')),
#  ('18.2-248', 'Unknown', 1373, Decimal('0.77')),
#  ('18.2-248', 'Asian or Pacific Islander', 640, Decimal('0.36')),
#  ('18.2-248', 'American Indian or Alaskan Native', 55, Decimal('0.03')),
#  ('18.2-250', 'White', 129101, Decimal('60.18')),
#  ('18.2-250', 'Black', 82492, Decimal('38.45')),
#  ('18.2-250', 'Asian or Pacific Islander', 1088, Decimal('0.51')),
#  ('18.2-250', 'Unknown', 895, Decimal('0.42')),
#  ('18.2-250', 'Hispanic', 887, Decimal('0.41')),
#  ('18.2-250', 'American Indian or Alaskan Native', 79, Decimal('0.04')),
#  ('18.2-250.1', 'White', 159370, Decimal('49.93')),
#  ('18.2-250.1', 'Black', 151334, Decimal('47.41')),
#  ('18.2-250.1', 'Hispanic', 3275, Decimal('1.03')),
#  ('18.2-250.1', 'Unknown', 2667, Decimal('0.84')),
#  ('18.2-250.1', 'Asian or Pacific Islander', 2428, Decimal('0.76')),
#  ('18.2-250.1', 'American Indian or Alaskan Native', 110, Decimal('0.03')),
#  ('18.2-388', 'White', 137556, Decimal('69.52')),
#  ('18.2-388', 'Black', 54714, Decimal('27.65')),
#  ('18.2-388', 'Unknown', 2745, Decimal('1.39')),
#  ('18.2-388', 'Hispanic', 1541, Decimal('0.78')),
#  ('18.2-388', 'Asian or Pacific Islander', 1102, Decimal('0.56')),
#  ('18.2-388', 'American Indian or Alaskan Native', 194, Decimal('0.10')),
#  ('18.2-57', 'White', 106538, Decimal('51.56')),
#  ('18.2-57', 'Black', 95373, Decimal('46.16')),
#  ('18.2-57', 'Unknown', 1986, Decimal('0.96')),
#  ('18.2-57', 'Asian or Pacific Islander', 1578, Decimal('0.76')),
#  ('18.2-57', 'Hispanic', 1031, Decimal('0.50')),
#  ('18.2-57', 'American Indian or Alaskan Native', 123, Decimal('0.06')),
#  ('18.2-95', 'White', 134296, Decimal('57.77')),
#  ('18.2-95', 'Black', 93575, Decimal('40.25')),
#  ('18.2-95', 'Asian or Pacific Islander', 1649, Decimal('0.71')),
#  ('18.2-95', 'Unknown', 1622, Decimal('0.70')),
#  ('18.2-95', 'Hispanic', 1241, Decimal('0.53')),
#  ('18.2-95', 'American Indian or Alaskan Native', 77, Decimal('0.03')),
#  ('18.2-96', 'White', 87718, Decimal('52.55')),
#  ('18.2-96', 'Black', 74948, Decimal('44.90')),
#  ('18.2-96', 'Asian or Pacific Islander', 1590, Decimal('0.95')),
#  ('18.2-96', 'Hispanic', 1481, Decimal('0.89')),
#  ('18.2-96', 'Unknown', 1092, Decimal('0.65')),
#  ('18.2-96', 'American Indian or Alaskan Native', 83, Decimal('0.05')),
#  ('19.2-128', 'Black', 68288, Decimal('55.13')),
#  ('19.2-128', 'White', 53046, Decimal('42.82')),
#  ('19.2-128', 'Hispanic', 1279, Decimal('1.03')),
#  ('19.2-128', 'Unknown', 796, Decimal('0.64')),
#  ('19.2-128', 'Asian or Pacific Islander', 411, Decimal('0.33')),
#  ('19.2-128', 'American Indian or Alaskan Native', 47, Decimal('0.04')),
#  ('19.2-306', 'White', 75354, Decimal('57.58')),
#  ('19.2-306', 'Black', 53693, Decimal('41.03')),
#  ('19.2-306', 'Hispanic', 787, Decimal('0.60')),
#  ('19.2-306', 'Unknown', 562, Decimal('0.43')),
#  ('19.2-306', 'Asian or Pacific Islander', 407, Decimal('0.31')),
#  ('19.2-306', 'American Indian or Alaskan Native', 69, Decimal('0.05')),
#  ('46.2-300', 'White', 265279, Decimal('47.57')),
#  ('46.2-300', 'Black', 150698, Decimal('27.02')),
#  ('46.2-300', 'Hispanic', 119032, Decimal('21.34')),
#  ('46.2-300', 'Unknown', 17197, Decimal('3.08')),
#  ('46.2-300', 'Asian or Pacific Islander', 5076, Decimal('0.91')),
#  ('46.2-300', 'American Indian or Alaskan Native', 428, Decimal('0.08')),
#  ('A.18.2-266', 'White', 192322, Decimal('71.74')),
#  ('A.18.2-266', 'Black', 63146, Decimal('23.55')),
#  ('A.18.2-266', 'Asian or Pacific Islander', 5037, Decimal('1.88')),
#  ('A.18.2-266', 'Hispanic', 3732, Decimal('1.39')),
#  ('A.18.2-266', 'Unknown', 3581, Decimal('1.34')),
#  ('A.18.2-266', 'American Indian or Alaskan Native', 262, Decimal('0.10')),
#  ('A.46.2-707', 'White', 60917, Decimal('54.29')),
#  ('A.46.2-707', 'Black', 43282, Decimal('38.57')),
#  ('A.46.2-707', 'Hispanic', 5645, Decimal('5.03')),
#  ('A.46.2-707', 'Unknown', 1452, Decimal('1.29')),
#  ('A.46.2-707', 'Asian or Pacific Islander', 863, Decimal('0.77')),
#  ('A.46.2-707', 'American Indian or Alaskan Native', 49, Decimal('0.04')),
#  ('A.46.2-852', 'White', 135546, Decimal('65.20')),
#  ('A.46.2-852', 'Black', 57039, Decimal('27.43')),
#  ('A.46.2-852', 'Hispanic', 6384, Decimal('3.07')),
#  ('A.46.2-852', 'Unknown', 4492, Decimal('2.16')),
#  ('A.46.2-852', 'Asian or Pacific Islander', 4154, Decimal('2.00')),
#  ('A.46.2-852', 'American Indian or Alaskan Native', 292, Decimal('0.14')),
#  ('A.46.2-853', 'White', 74517, Decimal('66.96')),
#  ('A.46.2-853', 'Black', 27909, Decimal('25.08')),
#  ('A.46.2-853', 'Hispanic', 4471, Decimal('4.02')),
#  ('A.46.2-853', 'Unknown', 2756, Decimal('2.48')),
#  ('A.46.2-853', 'Asian or Pacific Islander', 1436, Decimal('1.29')),
#  ('A.46.2-853', 'American Indian or Alaskan Native', 199, Decimal('0.18')),
#  ('A.46.2-862', 'White', 424557, Decimal('51.72')),
#  ('A.46.2-862', 'Black', 272307, Decimal('33.17')),
#  ('A.46.2-862', 'Unknown', 63276, Decimal('7.71')),
#  ('A.46.2-862', 'Hispanic', 41557, Decimal('5.06')),
#  ('A.46.2-862', 'Asian or Pacific Islander', 15711, Decimal('1.91')),
#  ('A.46.2-862', 'American Indian or Alaskan Native', 3461, Decimal('0.42')),
#  ('B.46.2-301', 'Black', 439888, Decimal('54.42')),
#  ('B.46.2-301', 'White', 338812, Decimal('41.92')),
#  ('B.46.2-301', 'Hispanic', 18747, Decimal('2.32')),
#  ('B.46.2-301', 'Unknown', 6250, Decimal('0.77')),
#  ('B.46.2-301', 'Asian or Pacific Islander', 4374, Decimal('0.54')),
#  ('B.46.2-301', 'American Indian or Alaskan Native', 207, Decimal('0.03')),
#  ('C.46.2-862', 'White', 193119, Decimal('53.63')),
#  ('C.46.2-862', 'Black', 122016, Decimal('33.89')),
#  ('C.46.2-862', 'Unknown', 20169, Decimal('5.60')),
#  ('C.46.2-862', 'Hispanic', 15614, Decimal('4.34')),
#  ('C.46.2-862', 'Asian or Pacific Islander', 8219, Decimal('2.28')),
#  ('C.46.2-862', 'American Indian or Alaskan Native', 950, Decimal('0.26'))]
